# %% [markdown]
# The Goal of this machine learning algorithm is to find the likelihood/risk level of diabetes based on a patients' life circumstances and current symptoms. Unfortunately, this data is not very generalizable, as the dataset is patients of Pima Indian Heritage.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier #Fixed typo in module name. Changed 'kneighbors' to 'neighbors'
from sklearn import svm
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

# %%
diabetes=pd.read_csv('/content/sample_data/diabetes.csv')
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_array=diabetes.to_numpy()
diabetes_array.shape
# Out:
# (768, 9)

# %% [markdown]
# After Creating these, we need to make/conduct pre-processing

# %%
from sklearn.preprocessing import StandardScaler

# Use the 'diabetes' DataFrame instead of 'df'
features_to_scale = ['Glucose', 'BloodPressure', 'SkinThickness','BMI','Insulin','Age']  # Example features from the diabetes dataset
X = diabetes[features_to_scale]
Y=diabetes['Outcome']

# Create a StandardScaler object
scaler = StandardScaler()

# Fit the scaler to your data and transform it
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# Alright, so now, we need to make the features and labels

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.15, random_state=42)
#model training

# %% [markdown]
# Now, we're going to introduce all of our ML algs

# %%
#Logistic Regression
log_reg=LogisticRegression()
log_reg.fit(X_train, y_train)
log_reg_pred=log_reg.predict(X_test)
print(accuracy_score(y_test, log_reg_pred))
# Out:
# 0.7413793103448276

# %%
#KNeighbors
knn=KNeighborsClassifier(n_neighbors=33)
knn.fit(X_train, y_train)
knn_pred=knn.predict(X_test)
print(accuracy_score(y_test, knn_pred))
# Out:
# 0.7413793103448276

# %%
#SVM
svm_model=svm.SVC(kernel="rbf", C=2.5)
svm_model.fit(X_train,y_train)
svm_pred=svm_model.predict(X_test)
print(accuracy_score(y_test, svm_pred))
# Out:
# 0.7327586206896551

# %%
#Radial basis function in SVM
rbf_kernel_svm_clf = svm.SVC(kernel="rbf", gamma=5, C=0.001)
rbf_kernel_svm_clf.fit(X_train, y_train)
print(accuracy_score(y_test, rbf_kernel_svm_clf.predict(X_test)))
# Out:
# 0.6551724137931034

# %%
#Random Forest
forest_clf=RandomForestClassifier(n_estimators=10,random_state=42)
forest_clf.fit(X_train, y_train)
print(accuracy_score(y_test, forest_clf.predict(X_test)))
# Out:
# 0.6982758620689655
